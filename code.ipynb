# %%
# Libraries
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
from sklearn import metrics
from sklearn.decomposition import TruncatedSVD

# %% [markdown]
# # PART 1

# %% [markdown]
# # Dimensional Reduction using Single Value Decomposition

# %%
# Reading HD Data 2 Dataset
data1 = pd.read_csv(r'C:\Users\sujal\Desktop\MA515group-16\HD Data 2.csv')

# %%
# Printing First 5 rows of the data set
data1.head()
# Out:
#    Unnamed: 0          1          2          3          4          5  \
# 0           0  40.527005  23.827908  70.151381  25.402995  51.205610
# 1           1  16.131192   3.417445  -4.161446  44.970951   9.048227
# 2           2  31.711781   1.921228  34.673047  50.258594  80.429873
# 3           3  22.344608  17.654925  -7.462117  11.181247   9.024700
# 4           4   1.463305  70.867143  26.463260  35.616958  11.806956
#
#            6          7          8          9  ...         41          42  \
# 0  -0.500565  14.055124  34.628477   9.124017  ...  18.064201    9.432148
# 1   1.652619   6.938698  15.127169  -6.665835  ...  24.769010  101.715152
# 2   0.171150  16.645188  33.591276  10.008848  ...  24.733085   12.553875
# 3  43.636999   5.731934  62.434215  34.540465  ...  13.562030   10.719871
# 4  35.414390  22.295906  27.546526  10.187778  ...  13.428348   45.668807
#
#           43         44         45         46         47         48  \
# ...

# %%
# Dropped column 1 (Representing serial number)
data1 = data1.drop(columns=['Unnamed: 0'])
data1.head()
# Out:
#            1          2          3          4          5          6  \
# 0  40.527005  23.827908  70.151381  25.402995  51.205610  -0.500565
# 1  16.131192   3.417445  -4.161446  44.970951   9.048227   1.652619
# 2  31.711781   1.921228  34.673047  50.258594  80.429873   0.171150
# 3  22.344608  17.654925  -7.462117  11.181247   9.024700  43.636999
# 4   1.463305  70.867143  26.463260  35.616958  11.806956  35.414390
#
#            7          8          9         10  ...         41          42  \
# 0  14.055124  34.628477   9.124017   7.538714  ...  18.064201    9.432148
# 1   6.938698  15.127169  -6.665835   4.690397  ...  24.769010  101.715152
# 2  16.645188  33.591276  10.008848  12.423936  ...  24.733085   12.553875
# 3   5.731934  62.434215  34.540465  -3.127112  ...  13.562030   10.719871
# 4  22.295906  27.546526  10.187778  38.988171  ...  13.428348   45.668807
#
#           43         44         45         46         47         48  \
# ...

# %%
#Size of the Data Set
data1.shape
# Out:
# (2500, 50)

# %%
X = data1

#Reducing the Data Size to 8 Columns 

svd = TruncatedSVD(n_components = 8)

#The new Dataset X_svd contains the new 8 columns 
X_svd = svd.fit_transform(X)

# Naming the columns and printing the final Dimensionally reduced SVD 
columns_svd = [f'SVD column {i+1}' for i in range (8)]
X_svd_df = pd.DataFrame(data = X_svd, columns = columns_svd)

X_svd_df
# Out:
#       SVD column 1  SVD column 2  SVD column 3  SVD column 4  SVD column 5  \
# 0       136.088101      0.873851     -5.320410     18.525642      4.706412
# 1       126.786754      1.014782     29.257541     21.455857     -9.142489
# 2       160.114194     39.342807    -34.335381      7.839792     31.304003
# 3       133.436736    -25.906289      0.482451      9.575189      1.274329
# 4       134.271905     30.355241     23.896868     -5.189725     13.048797
# ...            ...           ...           ...           ...           ...
# 2495    153.558632      1.683866     -5.004152     -9.728423      2.966806
# 2496    170.994438      8.823709     -7.877457     -9.353819      9.784336
# 2497    118.429057    -14.902769    -22.857622      1.980180      3.330494
# 2498    148.994184    -10.426285    -15.439903     20.516093      9.857359
# 2499    169.752612     -4.336108     -6.780533    -39.582631    -35.621505
#
#       SVD column 6  SVD column 7  SVD column 8
# ...

# %%
#Reducing the Data Size to 10 Columns 

svd = TruncatedSVD(n_components = 10)

#The new Dataset X_svd contains the new 10 columns 
X2_svd = svd.fit_transform(X)

# Naming the columns and printing the final Dimensionally reduced SVD 
columns_svd = [f'SVD column {i+1}' for i in range (10)]
X2_svd_df = pd.DataFrame(data = X2_svd, columns = columns_svd)

X2_svd_df
# Out:
#       SVD column 1  SVD column 2  SVD column 3  SVD column 4  SVD column 5  \
# 0       136.088101     11.706864     -3.225463     15.244291    -14.735653
# 1       126.786754     -4.522407    -19.226629     24.506194    -32.617851
# 2       160.114194     44.659350     32.292727     -1.125815     27.799176
# 3       133.436736    -29.809690     11.350279     -7.436937    -25.713958
# 4       134.271905     31.554610    -17.693822    -10.174028     25.715221
# ...            ...           ...           ...           ...           ...
# 2495    153.558632     15.903787     -0.691087    -14.138815     29.507697
# 2496    170.994438     11.570604     14.036687     18.291620     -5.239597
# 2497    118.429057    -13.775511     15.614612    -22.642480     16.515284
# 2498    148.994184      5.381945     14.855517      9.309863     43.584380
# 2499    169.752612    -24.656797      0.080283     16.562850    -45.703864
#
# ...

# %%
#Reducing the Data Size to 9 Columns 
svd = TruncatedSVD(n_components = 9)

#The new Dataset X_svd contains the new 9 columns 
X3_svd = svd.fit_transform(X)

# Naming the columns and printing the final Dimensionally reduced SVD 
columns_svd = [f'SVD column {i+1}' for i in range (9)]
data3 = pd.DataFrame(data = X3_svd, columns = columns_svd)

data3
# Out:
#       SVD column 1  SVD column 2  SVD column 3  SVD column 4  SVD column 5  \
# 0       136.088101      1.989286    -11.582050     -5.159893    -19.455201
# 1       126.786754     -8.663880     -3.150951     38.786848    -14.410793
# 2       160.114194     45.499108    -23.834530    -14.632127    -21.710337
# 3       133.436736    -32.399394      0.909001      8.838553      3.774779
# 4       134.271905     36.708484     22.325283      8.466336     44.292813
# ...            ...           ...           ...           ...           ...
# 2495    153.558632     16.809926     18.942224    -22.657522    -20.451151
# 2496    170.994438      8.534090    -15.814547      2.292766     -7.504475
# 2497    118.429057    -13.731746    -11.801094    -18.258898     -1.644946
# 2498    148.994184     -8.350662     10.506208    -15.718080    -43.312217
# 2499    169.752612    -21.619056    -22.742118      6.608528     -0.115073
#
#       SVD column 6  SVD column 7  SVD column 8  SVD column 9
# ...

# %% [markdown]
# # Exploratory Data Analysis

# %%
# Dimensional Reduced Data Set of HD Data 2 (9 columns)
data3
# Out:
#       SVD column 1  SVD column 2  SVD column 3  SVD column 4  SVD column 5  \
# 0       136.088101      1.989286    -11.582050     -5.159893    -19.455201
# 1       126.786754     -8.663880     -3.150951     38.786848    -14.410793
# 2       160.114194     45.499108    -23.834530    -14.632127    -21.710337
# 3       133.436736    -32.399394      0.909001      8.838553      3.774779
# 4       134.271905     36.708484     22.325283      8.466336     44.292813
# ...            ...           ...           ...           ...           ...
# 2495    153.558632     16.809926     18.942224    -22.657522    -20.451151
# 2496    170.994438      8.534090    -15.814547      2.292766     -7.504475
# 2497    118.429057    -13.731746    -11.801094    -18.258898     -1.644946
# 2498    148.994184     -8.350662     10.506208    -15.718080    -43.312217
# 2499    169.752612    -21.619056    -22.742118      6.608528     -0.115073
#
#       SVD column 6  SVD column 7  SVD column 8  SVD column 9
# ...

# %%
#Statstical Features of Data
data3.describe()
# Out:
#        SVD column 1  SVD column 2  SVD column 3  SVD column 4  SVD column 5  \
# count   2500.000000   2500.000000   2500.000000   2500.000000   2500.000000
# mean     141.343359      0.014150     -0.051491     -0.105382      0.033263
# std       20.941180     23.595283     23.199865     22.971034     22.763290
# min       75.504713    -80.324284    -88.019151    -67.419292    -75.531406
# 25%      126.858313    -15.714423    -15.112400    -15.629983    -14.761138
# 50%      140.586366     -0.330667      0.732199     -0.640060     -0.830822
# 75%      155.453336     14.816392     14.941636     13.852304     14.288104
# max      226.951887     94.846840     90.711505    143.467604     95.996722
#
#        SVD column 6  SVD column 7  SVD column 8  SVD column 9
# count   2500.000000   2500.000000   2500.000000   2500.000000
# mean       0.070397     -0.115538      0.000802     -0.042322
# std       22.595661     22.551677     22.351916     22.267188
# ...

# %%
# Checking the row names with NaN values.
data3.isnull().sum(axis=0)
# Out:
# SVD column 1    0
# SVD column 2    0
# SVD column 3    0
# SVD column 4    0
# SVD column 5    0
# SVD column 6    0
# SVD column 7    0
# SVD column 8    0
# SVD column 9    0
# dtype: int64

# %%
#Basic information regarding number of entries and memory usage and types of dtypes in the data set
data3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2500 entries, 0 to 2499
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   SVD column 1  2500 non-null   float64
#  1   SVD column 2  2500 non-null   float64
#  2   SVD column 3  2500 non-null   float64
#  3   SVD column 4  2500 non-null   float64
#  4   SVD column 5  2500 non-null   float64
#  5   SVD column 6  2500 non-null   float64
#  6   SVD column 7  2500 non-null   float64
#  7   SVD column 8  2500 non-null   float64
#  8   SVD column 9  2500 non-null   float64
# dtypes: float64(9)
# memory usage: 175.9 KB

# %%
# %matplotlib inline

#histogram plot
data3.hist(bins = 50 , figsize = (20,15))
# Out:
# array([[<Axes: title={'center': 'SVD column 1'}>,
#         <Axes: title={'center': 'SVD column 2'}>,
#         <Axes: title={'center': 'SVD column 3'}>],
#        [<Axes: title={'center': 'SVD column 4'}>,
#         <Axes: title={'center': 'SVD column 5'}>,
#         <Axes: title={'center': 'SVD column 6'}>],
#        [<Axes: title={'center': 'SVD column 7'}>,
#         <Axes: title={'center': 'SVD column 8'}>,
#         <Axes: title={'center': 'SVD column 9'}>]], dtype=object)

# %%
import seaborn as sns

#heatmap presentation of the correlations of attributes
sns.heatmap(data3.corr())
# Out:
# <Axes: >

# %%
import statsmodels.api as sm

# Function to create Q-Q plots for all columns
def qq_plots(data3):
    num_cols = data3.shape[1]
    num_rows = (num_cols + 2) // 3 
    fig, axes = plt.subplots(nrows=num_rows, ncols=3, figsize=(15, num_rows * 3))

    for i, column in enumerate(data3.columns):
        row_idx = i // 3
        col_idx = i % 3
        ax = axes[row_idx, col_idx] if num_rows > 1 else axes[col_idx]  # Handle single-row case
        sm.qqplot(data3[column], line='45', fit=True, ax=ax)
        ax.set_title(f'Q-Q Plot - {column}')


    plt.tight_layout()
    plt.show()

# Create Q-Q plots 
qq_plots(data3)

# %%
# Function to create pair plot with subplots in three rows

def pair_plot(data3):
    num_cols = data3.shape[1]
    num_rows = (num_cols + 2) // 3  
    fig, axes = plt.subplots(nrows=num_rows, ncols=3, figsize=(15, num_rows * 5))

    
    for i, column in enumerate(data3.columns):
        row_idx = i // 3
        col_idx = i % 3
        ax = axes[row_idx, col_idx] if num_rows > 1 else axes[col_idx]  # Handle single-row case
        sns.histplot(data3[column], kde=True, ax=ax)
        ax.set_title(f'Histogram - {column}')

   

    plt.tight_layout()
    plt.show()

# Create pair plot
pair_plot(data3)

# %% [markdown]
# # PART 2

# %%
# Reading Carseats Dataset
data2 = pd.read_csv(r'C:\Users\sujal\Desktop\MA515group-16\Carseats.csv')

# %%
# Showing the first 5 rows of dataset
data2.head()
# Out:
#    Unnamed: 0  Sales  CompPrice  Income  Advertising  Population  Price  \
# 0           1   9.50        138      73           11         276    120
# 1           2  11.22        111      48           16         260     83
# 2           3  10.06        113      35           10         269     80
# 3           4   7.40        117     100            4         466     97
# 4           5   4.15        141      64            3         340    128
#
#   ShelveLoc  Age  Education Urban   US
# 0       Bad   42         17   Yes  Yes
# 1      Good   65         10   Yes  Yes
# 2    Medium   59         12   Yes  Yes
# 3    Medium   55         14   Yes  Yes
# 4       Bad   38         13   Yes   No

# %%
# Dropped column 1(Representing serial number)
data2 = data2.drop(columns=['Unnamed: 0'])
data2.head()
# Out:
#    Sales  CompPrice  Income  Advertising  Population  Price ShelveLoc  Age  \
# 0   9.50        138      73           11         276    120       Bad   42
# 1  11.22        111      48           16         260     83      Good   65
# 2  10.06        113      35           10         269     80    Medium   59
# 3   7.40        117     100            4         466     97    Medium   55
# 4   4.15        141      64            3         340    128       Bad   38
#
#    Education Urban   US
# 0         17   Yes  Yes
# 1         10   Yes  Yes
# 2         12   Yes  Yes
# 3         14   Yes  Yes
# 4         13   Yes   No

# %%
# Showing predictor types
data2.dtypes
# Out:
# Sales          float64
# CompPrice        int64
# Income           int64
# Advertising      int64
# Population       int64
# Price            int64
# ShelveLoc       object
# Age              int64
# Education        int64
# Urban           object
# US              object
# dtype: object

# %% [markdown]
# # Exploratory Data Analysis

# %%
#Statstical Features of Data
data2.describe()
# Out:
#             Sales   CompPrice      Income  Advertising  Population  \
# count  400.000000  400.000000  400.000000   400.000000  400.000000
# mean     7.496325  124.975000   68.657500     6.635000  264.840000
# std      2.824115   15.334512   27.986037     6.650364  147.376436
# min      0.000000   77.000000   21.000000     0.000000   10.000000
# 25%      5.390000  115.000000   42.750000     0.000000  139.000000
# 50%      7.490000  125.000000   69.000000     5.000000  272.000000
# 75%      9.320000  135.000000   91.000000    12.000000  398.500000
# max     16.270000  175.000000  120.000000    29.000000  509.000000
#
#             Price         Age   Education
# count  400.000000  400.000000  400.000000
# mean   115.795000   53.322500   13.900000
# std     23.676664   16.200297    2.620528
# min     24.000000   25.000000   10.000000
# 25%    100.000000   39.750000   12.000000
# 50%    117.000000   54.500000   14.000000
# 75%    131.000000   66.000000   16.000000
# ...

# %%
# Checking the row names with NaN values.
data2.isnull().sum(axis=0)
# Out:
# Sales          0
# CompPrice      0
# Income         0
# Advertising    0
# Population     0
# Price          0
# ShelveLoc      0
# Age            0
# Education      0
# Urban          0
# US             0
# dtype: int64

# %%
#checking the size of data
data2.shape
# Out:
# (400, 11)

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Sales        400 non-null    float64
#  1   CompPrice    400 non-null    int64
#  2   Income       400 non-null    int64
#  3   Advertising  400 non-null    int64
#  4   Population   400 non-null    int64
#  5   Price        400 non-null    int64
#  6   ShelveLoc    400 non-null    object
#  7   Age          400 non-null    int64
#  8   Education    400 non-null    int64
#  9   Urban        400 non-null    object
#  10  US           400 non-null    object
# dtypes: float64(1), int64(7), object(3)
# memory usage: 34.5+ KB

# %%
# %matplotlib inline

data2.hist(bins = 50 , figsize = (20,15))
# Out:
# array([[<Axes: title={'center': 'Sales'}>,
#         <Axes: title={'center': 'CompPrice'}>,
#         <Axes: title={'center': 'Income'}>],
#        [<Axes: title={'center': 'Advertising'}>,
#         <Axes: title={'center': 'Population'}>,
#         <Axes: title={'center': 'Price'}>],
#        [<Axes: title={'center': 'Age'}>,
#         <Axes: title={'center': 'Education'}>, <Axes: >]], dtype=object)

# %%
NumericData = data2.drop(columns = ["ShelveLoc","US","Urban"], axis = 1)

#heatmap of correlation of dataset
sns.heatmap(NumericData.corr())
# Out:
# <Axes: >

# %%
# Function to create pair plot with subplots in three rows

def pair_plot(data2):
    num_cols = data2.shape[1]
    num_rows = (num_cols + 2) // 3  
    fig, axes = plt.subplots(nrows=num_rows, ncols=3, figsize=(15, num_rows * 5))

    
    for i, column in enumerate(data2.columns):
        row_idx = i // 3
        col_idx = i % 3
        ax = axes[row_idx, col_idx] if num_rows > 1 else axes[col_idx]  # Handle single-row case
        sns.histplot(data2[column], kde=True, ax=ax)
        ax.set_title(f'Histogram - {column}')

   # Remove any empty subplots if the number of columns is not a multiple of 3
    for i in range(num_cols, num_rows * 3):
        fig.delaxes(axes.flatten()[i])

    plt.tight_layout()
    plt.show()

# Create pair plot
pair_plot(data2)

# %%
import statsmodels.api as sm
import pylab as py
# qqplots to see attributes distribution

# Sales
sm.qqplot(data2.Sales.values, fit=True, line='45')
py.show()

# CompPrice
sm.qqplot(data2.CompPrice.values, fit=True, line='45')
py.show()

# Income
sm.qqplot(data2.Income.values, fit=True, line='45')
py.show()

# Advertising
sm.qqplot(data2.Advertising.values, fit=True, line='45')
py.show()

# Population
sm.qqplot(data2.Population.values, fit=True, line='45')
py.show()

# Price
sm.qqplot(data2.Price.values, fit=True, line='45')
py.show()

# Age
sm.qqplot(data2.Age.values, fit=True, line='45')
py.show()

# Education
sm.qqplot(data2.Education.values, fit=True, line='45')
py.show()

# %% [markdown]
# # Multiple Linear Regression

# %%
# Given Data, Sales attribute to be predicted, other attributes are predictors.
data2
# Out:
#      Sales  CompPrice  Income  Advertising  Population  Price ShelveLoc  Age  \
# 0     9.50        138      73           11         276    120       Bad   42
# 1    11.22        111      48           16         260     83      Good   65
# 2    10.06        113      35           10         269     80    Medium   59
# 3     7.40        117     100            4         466     97    Medium   55
# 4     4.15        141      64            3         340    128       Bad   38
# ..     ...        ...     ...          ...         ...    ...       ...  ...
# 395  12.57        138     108           17         203    128      Good   33
# 396   6.14        139      23            3          37    120    Medium   55
# 397   7.41        162      26           12         368    159    Medium   40
# 398   5.94        100      79            7         284     95       Bad   50
# 399   9.71        134      37            0          27    120      Good   49
#
#      Education Urban   US
# ...

# %% [markdown]
# # Data Pre Processing

# %%
#Separate the X and y from dataset.
X = data2.iloc[:,1:].values
y = data2.iloc[:,0].values
print('X')
print(X)
print('y')
print(y)
# Out:
# X
# [[138 73 11 ... 17 'Yes' 'Yes']
#  [111 48 16 ... 10 'Yes' 'Yes']
#  [113 35 10 ... 12 'Yes' 'Yes']
#  ...
#  [162 26 12 ... 18 'Yes' 'Yes']
#  [100 79 7 ... 12 'Yes' 'Yes']
#  [134 37 0 ... 16 'Yes' 'Yes']]
# y
# [ 9.5  11.22 10.06  7.4   4.15 10.81  6.63 11.85  6.54  4.69  9.01 11.96
#   3.98 10.96 11.17  8.71  7.58 12.29 13.91  8.73  6.41 12.13  5.08  5.87
#  10.14 14.9   8.33  5.27  2.99  7.81 13.55  8.25  6.2   8.77  2.67 11.07
#   8.89  4.95  6.59  3.24  2.07  7.96 10.43  4.12  4.16  4.56 12.44  4.38
#   3.91 10.61  1.42  4.42  7.91  6.92  4.9   6.85 11.91  0.91  5.42  5.21
#   8.32  7.32  1.82  8.47  7.8   4.9   8.85  9.01 13.39  7.99  9.46  6.5
#   5.52 12.61  6.2   8.55 10.64  7.7   4.43  9.14  8.01  7.52 11.62  4.42
#   2.23  8.47  8.7  11.7   6.56  7.95  5.33  4.81  4.53  8.86  8.39  5.58
#   9.48  7.45 12.49  4.88  4.11  6.2   5.3   5.07  4.62  5.55  0.16  8.55
#   3.47  8.98  9.    6.62  6.67  6.01  9.31  8.54  5.08  8.8   7.57  7.37
# ...

# %%
# Converting Object string of ShelveLoc, Urban, US to numbers

from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.compose import ColumnTransformer

labenc = LabelEncoder()
X[:,-1] = labenc.fit_transform(X[:,-1])
X[:,-2] = labenc.fit_transform(X[:,-2])
X[:,5] = labenc.fit_transform(X[:,5])

print(X)
# Out:
# [[138 73 11 ... 17 1 1]
#  [111 48 16 ... 10 1 1]
#  [113 35 10 ... 12 1 1]
#  ...
#  [162 26 12 ... 18 1 1]
#  [100 79 7 ... 12 1 1]
#  [134 37 0 ... 16 1 1]]

# %%
# Column Transformation on ShelveLoc, Urban, US transformed attributes
ct = ColumnTransformer([('encoder', OneHotEncoder(), [-1,-2,5])],remainder='passthrough')
X = np.array(ct.fit_transform(X))

print(X)
# Out:
# [[0.0 1.0 0.0 ... 120 42 17]
#  [0.0 1.0 0.0 ... 83 65 10]
#  [0.0 1.0 0.0 ... 80 59 12]
#  ...
#  [0.0 1.0 0.0 ... 159 40 18]
#  [0.0 1.0 0.0 ... 95 50 12]
#  [0.0 1.0 0.0 ... 120 49 16]]

# %% [markdown]
# # Predicting Sales

# %%
# Libraries
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
# Splitting data into training and testing
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=4)

reg = LinearRegression()

# %%
# Fitting the data using Linear Regression model
reg.fit(X_train, y_train)

# Predicting y on test dataset
y_pred = reg.predict(X_test)

# %%
print(f'Rows in train set : { len(X_train )}\nRows in test set : {len(X_test)}\n')
# Out:
# Rows in train set : 280
# Rows in test set : 120

# %%
# Predicted values of sales
print(y_pred)
# Out:
# [ 8.98438764  6.24118555  6.29645627  5.90464549  6.66120208  8.60873875
#  13.27255071  5.95541113  7.23690905  5.56314427 10.47046783  5.89746864
#   8.79283636 11.16080824  9.90600111  6.59208913 11.71696234  6.53267266
#   4.91017333  9.46685216  7.74066379  9.69423367  9.4858965   5.13932305
#   4.91476537  2.65889391  3.12366023  5.16804745  6.67920362  6.9187807
#   5.94986793 10.00310689  7.31647698  8.8760344   4.67510382  6.86296291
#   6.30595712  4.52553912  5.52004593 11.97487802  7.76233076  5.42046614
#  11.30186598  4.38005997 13.48750143  5.40923976  6.51060812  6.89152464
#   5.61774826 10.01697423  7.39435927 10.79529124  8.73188271  7.58712228
#  12.21639746  9.75317102  9.63766685  2.56638727  8.82139748 10.60448464
#  12.13653724  7.30031248 11.69699332  8.353842    4.62973554 10.96353274
#  12.16348859 12.69574052 15.90769631  6.28609198  6.0589797  10.96689746
#  10.51166498  4.40334702  8.79832239  7.14330028  9.29807336 13.16263619
# ...

# %%
# Actual sales value in test dataset
print(y_test)
# Out:
# [ 9.95  6.63  7.32  6.8   4.11  7.22 14.37  5.86  6.64  4.99 12.01  4.38
#   9.46 11.7   8.87  6.38 11.96  4.53  6.85  8.85  6.18 10.27 11.17  3.47
#   4.2   5.04  3.9   5.4   5.52  6.71  5.35 10.14  7.62  8.01  5.68  6.87
#   3.58  4.94  4.42 10.96  7.8   4.47 11.62  3.67 14.9   5.01  7.56  5.83
#   5.53 10.5   6.41  9.03  6.89  7.8  11.99  9.48  8.64  2.23  7.72  9.58
#  12.85  7.41 11.48  8.23  2.67 10.71 13.39 12.3  16.27  5.32  6.71  9.4
#  11.93  5.28  9.39  8.19  8.78 13.28  6.68  8.65  5.93 10.43 11.54  4.96
#   5.3   7.44  7.38 13.91 11.19  4.21  4.97  4.12 11.22  5.07  0.16  4.53
#   8.47  5.55 10.08  6.88  8.32  7.64  3.98 12.04  7.52  7.22  5.56  8.44
#  12.11 10.62  9.71  7.95  4.95  4.56  6.59  7.63  8.07 10.    7.41  8.86]

# %%
# Regression coefficient
reg.coef_
# Out:
# array([ 1.21764962e-01, -1.21764962e-01, -5.33085785e-02,  5.33085785e-02,
#        -2.25186439e+00,  2.53136111e+00, -2.79496720e-01,  9.39027222e-02,
#         1.42404765e-02,  1.30157013e-01,  1.30621176e-04, -9.57611854e-02,
#        -4.36518640e-02, -1.97451934e-02])

# %%
# Intercept value
reg.intercept_
# Out:
# 7.783335966340478

# %%
# Regression score
reg.score(X_test, y_test)
# Out:
# 0.8834699579060775

# %%
predicted = reg.predict(X_test)

print(X_test)
# Out:
# [[0.0 1.0 1.0 ... 97 60 11]
#  [1.0 0.0 0.0 ... 108 71 15]
#  [1.0 0.0 1.0 ... 107 26 13]
#  ...
#  [0.0 1.0 1.0 ... 88 57 10]
#  [0.0 1.0 0.0 ... 87 57 16]
#  [1.0 0.0 0.0 ... 104 55 17]]

# %%
predicted.shape
# Out:
# (120,)

# %%
df = pd.DataFrame(y_test,predicted)

dfr = pd.DataFrame({'Actual Price':y_test,'Predicted Price':predicted})

print(dfr)
# Out:
#      Actual Price  Predicted Price
# 0            9.95         8.984388
# 1            6.63         6.241186
# 2            7.32         6.296456
# 3            6.80         5.904645
# 4            4.11         6.661202
# ..            ...              ...
# 115          7.63         7.059147
# 116          8.07         6.921945
# 117         10.00        10.370275
# 118          7.41         6.946677
# 119          8.86         9.035089
#
# [120 rows x 2 columns]

# %% [markdown]
# # Errors from Prediction Model

# %%
from sklearn.metrics import confusion_matrix,accuracy_score 
import math

print('Mean Absolute Error : ', metrics.mean_absolute_error(y_test,predicted))
# Out:
# Mean Absolute Error :  0.8251075181301659

# %%
print('Mean Squared Error : ', metrics.mean_squared_error(y_test,predicted))
# Out:
# Mean Squared Error :  1.038539720098799

# %%
print('Root Mean Squared Error : ', math.sqrt(metrics.mean_squared_error(y_test,predicted)))
# Out:
# Root Mean Squared Error :  1.019087690092859

# %%
graph = dfr.head(50)

graph.plot(kind = 'bar',width = 0.5)
# Out:
# <Axes: >

# %% [markdown]
# # Lasso Regression

# %%
# Lasso Regression with different lambdas
from sklearn.linear_model import Lasso
from sklearn.model_selection import train_test_split

lambdas = (0.001, 0.01, 0.1, 0.5, 1, 2, 10)
for ind, i in enumerate(lambdas):  
    reg = Lasso(alpha = i)
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 4)
    reg.fit(X_train,y_train)
    y_pred = reg.predict(X_test)
    print("\nLambda value :", i)
    print("Regression Coefficients\t", reg.coef_)
    print("Regression score", reg.score(X_test, y_test))
# Out:
# Lambda value : 0.001
# Regression Coefficients	 [ 2.34271769e-01 -0.00000000e+00 -1.00940978e-01  9.20172615e-16
#  -1.96810884e+00  2.80470231e+00 -0.00000000e+00  9.39156755e-02
#   1.42378897e-02  1.29685906e-01  1.34134402e-04 -9.57436711e-02
#  -4.36456241e-02 -1.96304670e-02]
# Regression score 0.8834597923337516
#
# Lambda value : 0.01
# Regression Coefficients	 [ 1.51462517e-01 -4.16356868e-17 -4.97751304e-02  0.00000000e+00
#  -1.92969546e+00  2.74930447e+00 -0.00000000e+00  9.40327398e-02
#   1.42141645e-02  1.25477438e-01  1.65400852e-04 -9.55858495e-02
#  -4.35888682e-02 -1.86085508e-02]
# Regression score 0.883058298125995
#
# Lambda value : 0.1
# Regression Coefficients	 [ 0.00000000e+00 -0.00000000e+00 -0.00000000e+00  0.00000000e+00
#  -1.56929840e+00  2.24122158e+00  0.00000000e+00  9.37968507e-02
#   1.41122745e-02  1.17107173e-01  2.51554224e-04 -9.40021225e-02
#  -4.32306186e-02 -1.13501449e-02]
# Regression score 0.8649118612794333
#
# Lambda value : 0.5
# ...
